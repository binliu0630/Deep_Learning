# %% [markdown]
# <a href="https://colab.research.google.com/github/smitaforward/Data_Science/blob/master/Copy_of_gpt_2_playground_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-2 Playground
#
# ## Background
# In this Jupyter notebook you can play around with the small version (117M) of **Open AI's GPT-2** Model from the paper *[Language Models are Unsupervised Multitask Learners](https://d4mucfpksywv.cloudfront.net/better-language-models/language-models.pdf).*
#
# According to the authors, the GPT-2 algorithm was trained on the task of *language modeling*--- which tests a program's ability to predict the next word in a given sentence--by ingesting huge numbers of articles, blogs, and websites. By using just this data it achieved state-of-the-art scores on a number of unseen language tests, an achievement known as *zero-shot learning.* It can also perform other writing-related tasks, like translating text from one language to another, summarizing long articles, and answering trivia questions.
#
# Open AI decided not to release the dataset, training code, or the full GPT-2 model weights. This is due to the concerns about large language models being used to generate deceptive, biased, or abusive language at scale. Some examples of the applications of these models for malicious purposes are:
# * Generate misleading news articles
# * Impersonate others online
# * Automate the production of abusive or faked content to post on social media
# * Automate the production of spam/phishing content
#
# As one can imagine, this combined with recent advances in generation of synthetic imagery, audio, and video implies that it's never been easier to create fake content and spread disinformation at scale. The public at large will need to become more skeptical of the content they consume online.
#
# ## Steps
# Before starting, is recommended to set *Runtime Type* to *GPU* on the top menu bar.
#
#
# ###1. Installation
# Download the model data and istall Python libraries:

# %%
# !git clone https://github.com/ilopezfr/gpt-2/
import os
os.chdir('gpt-2')
# !sh download_model.sh 117M
# !pip3 install -r requirements.txt
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 67 (delta 2), reused 0 (delta 0), pack-reused 61
# Unpacking objects: 100% (67/67), done.
# Copying gs://gpt-2/models/117M/checkpoint...
# / [1 files][   77.0 B/   77.0 B]
# Operation completed over 1 objects/77.0 B.
# Copying gs://gpt-2/models/117M/encoder.json...
# / [1 files][ 1017 KiB/ 1017 KiB]
# Operation completed over 1 objects/1017.9 KiB.
# Copying gs://gpt-2/models/117M/hparams.json...
# / [1 files][   90.0 B/   90.0 B]
# Operation completed over 1 objects/90.0 B.
# Copying gs://gpt-2/models/117M/model.ckpt.data-00000-of-00001...
# \ [1 files][474.7 MiB/474.7 MiB]
# Operation completed over 1 objects/474.7 MiB.
# Copying gs://gpt-2/models/117M/model.ckpt.index...
# / [1 files][  5.1 KiB/  5.1 KiB]
# Operation completed over 1 objects/5.1 KiB.
# Copying gs://gpt-2/models/117M/model.ckpt.meta...
# / [1 files][460.1 KiB/460.1 KiB]
# Operation completed over 1 objects/460.1 KiB.
# Copying gs://gpt-2/models/117M/vocab.bpe...
# / [1 files][445.6 KiB/445.6 KiB]
# Operation completed over 1 objects/445.6 KiB.
# Collecting fire>=0.1.3 (from -r requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/5a/b7/205702f348aab198baecd1d8344a90748cb68f53bdcd1cc30cbc08e47d3e/fire-0.1.3.tar.gz
# Requirement already satisfied: tensorflow>=1.12 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (1.13.0rc1)
# Collecting regex==2017.4.5 (from -r requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/36/62/c0c0d762ffd4ffaf39f372eb8561b8d491a11ace5a7884610424a8b40f95/regex-2017.04.05.tar.gz (601kB)
#     100% |████████████████████████████████| 604kB 20.4MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from fire>=0.1.3->-r requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.13.0rc0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: tensorboard<1.13.0,>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.12.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.0.7)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.14.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (0.33.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=1.12->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow>=1.12->-r requirements.txt (line 2)) (40.8.0)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0rc0->tensorflow>=1.12->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: werkzeug>=0.11.10 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow>=1.12->-r requirements.txt (line 2)) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow>=1.12->-r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow>=1.12->-r requirements.txt (line 2)) (2.8.0)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python3.6/dist-packages (from mock>=2.0.0->tensorflow-estimator<1.14.0rc0,>=1.13.0rc0->tensorflow>=1.12->-r requirements.txt (line 2)) (5.1.2)
# Building wheels for collected packages: fire, regex
#   Building wheel for fire (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/2a/1a/4d/6b30377c3051e76559d1185c1dbbfff15aed31f87acdd14c22
#   Building wheel for regex (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/75/07/38/3c16b529d50cb4e0cd3dbc7b75cece8a09c132692c74450b01
# Successfully built fire regex
# spacy 2.0.18 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# spacy 2.0.18 has requirement regex==2018.01.10, but you'll have regex 2017.4.5 which is incompatible.
# Installing collected packages: fire, regex
#   Found existing installation: regex 2018.1.10
#     Uninstalling regex-2018.1.10:
#       Successfully uninstalled regex-2018.1.10
# Successfully installed fire-0.1.3 regex-2017.4.5

# %%
os.listdir()
# Out:
# ['samples',
#  'models',
#  'download_model.sh',
#  'gpt-2-playground.ipynb',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'src',
#  'gpt2-samples.txt',
#  'gpt-2-playground_.ipynb',
#  'README.md',
#  '.git',
#  'requirements.txt']

# %% [markdown]
# ###  2. Unconditional sample generation
#
# WARNING: Samples are unfiltered and may contain offensive content.
#
# To generate unconditional samples from the small model:
# ```
# !python3 src/generate_unconditional_samples.py
# ```
# There are a few flags available.
# - `nsamples`: specify the number of samples you want to print
# - `length`: number of tokens (words) to print on each sample
# - `batch_size`
# - `temperature`: ??
# - `top_k`: ??

# %%
# !python3 src/generate_unconditional_samples.py --nsamples=2 --top_k=40 --temperature=0.7 | tee samples
# Out:
# 2019-02-17 14:22:27.947621: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-02-17 14:22:27.947991: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1b76f20 executing computations on platform Host. Devices:
# 2019-02-17 14:22:27.948028: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-17 14:22:28.117071: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-17 14:22:28.118061: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1b76c60 executing computations on platform CUDA. Devices:
# 2019-02-17 14:22:28.118129: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-02-17 14:22:28.118538: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-02-17 14:22:28.118571: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-02-17 14:22:29.086984: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-02-17 14:22:29.087065: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-02-17 14:22:29.087085: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-02-17 14:22:29.087359: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-02-17 14:22:29.087495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10754 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:53: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2019-02-17 14:22:35.332839: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ======================================== SAMPLE 1 ========================================
# (Reuters) - The United States will take legal action against Saudi Arabia over a series of air strikes in Yemen that killed more than 300 people, a U.S. military official said on Tuesday.
#
# U.S. President Barack Obama delivers a speech at the United Nations in New York January 8, 2012. REUTERS/Lucas Jackson
#
# The United States has called for the Saudi-led coalition to withdraw from a disputed town in Yemen to allow humanitarian aid to reach its people.
#
# The United States has said it is "deeply concerned" about the air strikes and urged its Saudi-led coalition to withdraw.
#
# The official, who asked not to be identified, said that the United States was seeking an "unprecedented military response" to the incidents.
#
# "We will not allow the Saudis to do this," the official said, speaking on condition of anonymity because he was not authorized to discuss the matter.
#
# The Pentagon said in a statement that it would not comment on specific actions by the United States.
#
# "The U.S. will vigorously defend the sovereignty of our friends and allies in Yemen," the statement read.
#
# The incident was the latest in a string of attacks in the country on Tuesday, including a suicide bombing on a shopping mall in the capital Sanaa that killed at least 20 people.
#
# U.S. officials said the United States was looking to "clear the air" of the Saudi-led coalition.
#
# The attack on the mall is believed to be the latest escalation in a wave of attacks on civilians in Yemen in recent years.
#
# The Saudi-led coalition has been in a state of emergency since March 2011, when a coalition of allied Sunni states backed by the United States launched a ground campaign to topple President Ali Abdullah Saleh.
#
# The United States has been accused of supporting the Sunni extremists in Yemen, which has been gripped by civil war since 2011.<|endoftext|>Dishonored 2 is a video game that is based on the popular Danganronpa series developed by Square Enix. It is a remake of the original game and features a lot of cutscenes, and the gameplay is much the same as the original game.
#
# Contents show]
#
# Gameplay Edit
#
# The game is currently very similar to the original PlayStation 3 version of Dishonored, and has a good mix of cutscenes and gameplay, but is a bit different in the way that it deals with the game's story. The music is quite similar in the way that it features the game's protagonist, Danganronpa. The game also has some new features, such as the ability to talk to the protagonist, and the ability to listen to the protagonist's voice.
#
# In addition to the story, there are several other interesting additions to the game.
#
# The game's graphics are somewhat similar to the original Playstation 3 version. Instead of 4 color screens, the PS3 version now has a 3D graphics with 24 colors. The PS3 version also has the ability to play 3D games in 3D. The game also has a new sound system, which was also introduced in the game.
#
# The game's voice actors are both voiced by a new voice actor, who also voices the protagonist.
#
# There is a new feature for the game called the "voice recorder", which can be used to record and share voice transcripts. In addition, the voice recorder has the ability to record and share audio files for the game.
#
# The game has a new "Story Mode" called "Chapters". The "Chapters" feature the story of Danganronpa and the character interactions of the two protagonists. There are also new "Story Mode" events, which are different in the way they are narrated, and the "Story Mode" events have more dialogue for the two characters.
#
# There are also new character endings and new story missions to complete.
#
# The "Story Mode" has one additional feature, which is called "Character Dialogue" which consists of a series of short, short sentences which can be read in the same order. The dialogue is extremely similar to the original PlayStation 3 version. The "Character Dialogue" features the character's dialogue, which can be read as follows:
#
# "So, you're going to be the last Danganronpa protagonist. So, where did you come from? What are the circumstances of your life? And your family? And your friends? You will be taken to a very dark place. You will end up living in a dark place, where the only hope is to be able to save Danganronpa."
#
# The ending of the story mode has a new "Cultural Mode", which consists of a short short speech which can be read in the same order as the original PlayStation 3 version. It is not the same as the original PlayStation 3 version. "So, you're going to be the last Danganronpa protagonist. So, where did you come from? What are the circumstances of your
# ======================================== SAMPLE 2 ========================================
#
# The Department of Energy (DOE) has been working on a plan for reforming the fuel economy. This new energy policy is aimed at cutting emissions from gasoline, diesel and coal, while reducing CO2 emissions and reducing greenhouse gas emissions.
#
# The plan, which was first announced in July, is based on a proposal from the U.S. Department of Energy's Clean Energy Plan (CEP). The plan has been finalized by the Office of Management and Budget.
#
# The DOE proposes to raise the CO2 level from 0.01 parts per million (ppm) to 1 ppm. The proposed change will be implemented within 10 years. The plan will be implemented in 2020.
#
# The DOE's Clean Energy Plan, which is designed to address the most pressing issues related to the U.S. economy, is a set of policies designed to promote economic growth and job creation through cleaner energy technologies.
#
# "The DOE Plan has been in the works for a long time. It's a way for the nation to share its efforts to reduce CO2 emissions with the world. This plan will be the first to address the most urgent challenges facing the country's future energy economy," said Secretary of Energy Ernest Moniz.
#
# "This plan will ensure that America's energy sources are fully supported across the U.S. and bring the United States of America to a low carbon economy. This plan will also ensure that our nation's energy needs are met without jeopardizing our future economic growth and jobs," said Secretary Moniz.
#
# The DOE's Clean Energy Policy would be released on April 2, 2017, which includes a five-page plan that outlines the process for the Clean Energy Plan from the DOE to the Secretary of Energy. Currently, the DOE is working on the Clean Energy Policy.
#
# The plan also includes a set of recommendations for the DOE to implement the Clean Energy Plan through the Clean Energy Technology Program (CEPT).
#
# The DOE plans to:
#
# Improve energy efficiency to reduce CO2 emissions
#
# Provide incentives to help the U.S. to achieve its energy goals
#
# Improve energy efficiency by reducing CO2 emissions to meet the energy needs of the American people
#
# Reduce CO2 emissions to meet the energy needs of American workers
#
# Ensure that Americans are getting the energy they need to keep the nation on a sustainable path to achieving its energy goals
#
# The Clean Energy Policy will be released in early 2018.
#
# ###
#
# Related articles<|endoftext|>A new study has shown that women who are over 65 years old are twice as likely as those with a college degree to have a family member on their father's watch list. The findings are published in the journal BMJ Open.
#
# The finding is consistent with the results of a 2013 study of adults who had never been to an abortion and did not have a family member on a father's watch list.
#
# This study, which was not published in the peer-reviewed journal, was conducted over a period of 6 months. It found a significant increase in the presence of a family member on the father's watch list for both men and women over 65 years old.
#
# "The findings suggest that the importance of family members for family planning decisions may be well-established and can be strengthened by the growing number of studies of family planning."
#
# The study was based on data from the National Family Planning Survey (NFPS) which covers 2,200 adults aged 10-54. Researchers found that women were more likely than men to have a family member on a father's watch list (43% vs. 28%) and to have a family member on a mother's watch list (35% vs. 19%).
#
# Women were more likely than men to have a family member on a mother's watch list (43% vs. 28%) and to have a family member on a father's watch list (35% vs. 19%). Women were less likely than men to have a family member on a mother's watch list (41% vs. 39%) and to have a family member on a father's watch list (29% vs. 22%).
#
# Women were more likely than men to have a family member on a mother's watch list (41% vs. 39%) and to have a family member on a father's watch list (29% vs. 22%). Women were more likely than men to have a family member on a mother's watch list (41% vs. 39%) and to have a family member on a father's watch list (29% vs. 22%). Women were less likely than men to have a family member on a mother's watch list (41% vs. 39%) and to have a family member on a father's watch list (29% vs. 22%).
#
# Women were also more likely than men to have a family member on a mother's watch list (41% vs. 39%) and to have a family member on a father's watch list (29% vs. 22%). Women were less likely than men to

# %%
# !python3 src/generate_unconditional_samples.py --nsamples=2 --top_k=2
# Out:
# 2019-02-17 14:24:07.035789: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-02-17 14:24:07.036110: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x27c2680 executing computations on platform Host. Devices:
# 2019-02-17 14:24:07.036147: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-17 14:24:07.132866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-17 14:24:07.133407: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x27c35a0 executing computations on platform CUDA. Devices:
# 2019-02-17 14:24:07.133441: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-02-17 14:24:07.133794: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-02-17 14:24:07.133826: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-02-17 14:24:07.520414: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-02-17 14:24:07.520502: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-02-17 14:24:07.520523: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-02-17 14:24:07.520816: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-02-17 14:24:07.520896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10754 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:53: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2019-02-17 14:24:13.590705: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ======================================== SAMPLE 1 ========================================
#
# A man who was arrested for allegedly stealing a car from a convenience store in the city of St. Louis was released from jail Thursday after posting a $1,000 bond, according to the St. Louis County District Attorney's Office.
#
# Michael J. Johnson, 24, of the 600 block of South Main St., was charged with two counts of theft and two counts of possession of stolen property.
#
# Johnson was released from the St. Louis County Jail after posting $1,000 bond, the St. Louis County District Attorney's Office said in a news release.
#
# The incident happened at about 8:30 p.m., when Johnson was driving a white Ford Explorer in the 300 block of South Main Street, according to the St. Louis County District Attorney's Office.
#
# The vehicle, which was parked in a back alley of the store, was parked on the sidewalk and was not visible to anyone in the store, the DA's office said in the news release.
#
# The vehicle was not stolen, the DA's Office said.
#
# The vehicle, which was not visible to anyone in the store, was not stolen, the DA's office said.
#
# Johnson was arrested on charges of theft and two counts of possession of stolen property, the DA's office said.
#
# Karp said the findings are important because they suggest that the ability to process information from a single source can be altered over time.
#
# "This is the first time we have found that a single source can change the brain's ability to process information," he said. "This is the first time we have found that a single source can change the brain's ability to process information."
#
# The researchers also found that when the individual was not in a specific place at the time, the brain's ability to process information was significantly reduced.
#
# The researchers found that when the individual was not in a specific place at the time, the brain's ability to process information was significantly reduced.
#
# "This is a very interesting result because it shows that the brain is able to process information from a single source," said Karp. "It's a very interesting result because it shows that the brain is able to process information from a single source."
#
# The researchers found that when the individual was not in a specific place at the time, the brain's ability to process information was significantly reduced.
#
# The results suggest that the brain is capable of processing information from a single source.
#
# "This is the first time we have found that a single source can change the brain's ability to process information," said Karp, who is also a postdoctoral fellow at the University of Michigan. "This is the first time we have found that a single source can change the brain's ability to process information."
#
# The findings are important because they suggest that the ability to process information from a single source can be altered over time.
#
# The researchers found that when the individual was not in a specific place at the time, the brain's ability to process information was significantly reduced.
#
# "This is a very interesting result because it shows that the brain is capable of processing information from a single source," said Karp, who is also a postdoctoral fellow at the University of Michigan. "It's not just a single source, but a whole set of sources."
#
# The researchers found that when the individual was not in a specific place at the time, the brain's ability to process information was significantly reduced.
#
# "This is a very interesting result because it shows that the brain is capable of processing information from a single source," said Karp, who is also a postdoctoral fellow at the University of Michigan. "It's not just a single source, but a whole set of sources."
#
# The researchers found that when the individual was not in a specific place at the time, the brain's ability to process information was significantly reduced.
#
# "This is a very interesting result because it shows that the brain is capable of processing information from a single source," said Karp, who is also a postdoctoral fellow at the University of Michigan. "It's not just a single source, but a whole set of sources."

# %%
# !python3 src/generate_unconditional_samples.py --nsamples=2 --top_k=80

# %% [markdown]
# ## Conditional sample generation
#
# To generate conditional samples from the small model:
# ```
# !python3 src/interactive_conditional_samples.py
# ```
# It comes with a few flags available:
# - `nsamples`: specify the number of samples you want to print
# - `length`
# - `batch_size`
# - `temperature`
# - `top_k`
#
# The authors tested the model performance on a few different language tasks, including **reading comprehension, summarization, translation, and question-answering.**
#
# Below are a few examples selected to test the aforementioned behaviors:

# %% [markdown]
# ### 1. Text Completion
#
# - Context: random unseen text
#
# Sample prompt 1:
# ```
# In a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the Andes Mountains. Even more surprising to the researchers was the fact that the unicorns spoke perfect English.
# ```
#
# Sample prompt 2: ([*Voight-Kampff test*](https://www.youtube.com/watch?v=Umc9ezAyJv0))
#
# ```
# You're in a desert, walking along in the sand, when all of a sudden you look down and see a tortoise, Leon. It's crawling toward you. You reach down, you flip the tortoise over on its back. The tortoise lays on its back, its belly baking in the hot sun, beating its legs trying to turn itself over, but it can’t, not without your help. But you’re not helping. Why is that?
# ```
#
# Sample prompt 3:
# ```
# I've seen things you people wouldn't believe. Attack ships on fire off the shoulder of Orion. I watched C-beams glitter in the dark near the Tannhäuser Gate. All those moments will be lost in time, like tears in rain. Time to die.
# ```
#
# Sample prompt 4:
# ```
# Outfit 1: Typical This pairing was the first outfit I thought of when I bought the shoes. It’s like a summer version of this Jake Grantham outfit; in fact, my shoes are close to the colors of his Nike Racers! Instead of a heavy Harris Tweed jacket and denim shirt, I’m wearing a cotton DB jacket and and a linen shirt. Both fabrics (in these colors) are an absolute must for summer, as they go with both dark and and light pants! As you can see, they pair wonderfully with the dark jeans and shoes. It’s a pseudo menswear/prep outfit. Overall, this is a very casual outfit which is why I paired my sneakers with it. I’m not about wearing a full wool suit with sneakers (as GQ shows a lot) but I’m definitely open to keeping things casual, like this cotton DB. Casual fabrics are key to pulling off your sneakers in a dressed down menswear outfit. I’d even suggest to wear these sneakers with a khaki chino suit or a white linen suit. Just be sure to ditch the tie or wear a tee or polo; wearing a tie with sneakers is a bit too much
# ```
# Sample prompt 5:
# ```
# - Some of the most glorious historical attractions in Spain date from the period of Muslim rule, including The Mezquita, built as the Great Mosque of Cordoba and the Medina Azahara, also in Cordoba, the Palace of al-Andalus; and the Alhambra in Granada, a splendid, intact palace.
# ```
# Sample prompt 6:
# ```
# How can Artificial Intelligence be dangerous? Most researchers agree that a superintelligent AI is unlikely to exhibit human emotions like love or hate, and that there is no reason to expect AI to become intentionally benevolent or malevolent. Instead, when considering how AI might become a risk, experts think two scenarios most likely:
# ```
# Sample prompt 7:
# ```
# Our solar system consists of the inner and outer planets, separated by an asteroid belt. It has
# ```
# Sample prompt 8:
# ```
# The 10 best foods are: 1. Serrano Ham 2. Manchego Cheese 3.
# ```
# Sample prompt 9:
# ```
# Real Madrid boss Santiago Solari admitted his team put in a 'weak performance' in their 1-0 Copa del Rey loss to local rivals Leganes. Despite losing the game, Los Blancos will progress to the quarter final stages of the tournament, winning the tie 3-1 on aggregate thanks to a 3-0 victory in the first leg. "It was a difficult game, but the performance was weak," Real Madrid boss Santi Solari on the
# ```
# Sample prompt 10:
# ```
# Roses are read, violets are blue,
# ```

# %%
# !python3 src/interactive_conditional_samples.py --nsamples=2 --top_k=40 --temperature=.80
# Out:
# 2019-02-17 14:28:05.780240: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-02-17 14:28:05.780542: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1872680 executing computations on platform Host. Devices:
# 2019-02-17 14:28:05.780593: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-17 14:28:05.874911: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-17 14:28:05.875438: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x18735a0 executing computations on platform CUDA. Devices:
# 2019-02-17 14:28:05.875476: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-02-17 14:28:05.875857: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-02-17 14:28:05.875910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-02-17 14:28:06.252501: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-02-17 14:28:06.252573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-02-17 14:28:06.252596: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-02-17 14:28:06.252911: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-02-17 14:28:06.252977: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10754 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:53: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Model prompt >>> Roses are read, violets are blue,
# 2019-02-17 14:28:42.702829: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
#
# ======================================== SAMPLE 1 ========================================
#  but can be red and green (for details about the colors you can see in this table, see the chart).
#
# The color of the violets is the same as the color of the water.
#
# This table shows the colors of the water that are yellow and green.
#
# Water is the primary color of the water that is yellow and green. As a general rule, it is the most commonly used color in the U.S. for aquatic systems. It indicates that there are many kinds of plants that are able to live in the same water. However, it is much less frequent in tropical water (like freshwater), where there is a need for more green in the water (like in the ocean).
#
# Some plants can grow to yellow and green in tropical water. These plants are called the 'greenies' or 'yellowies'. These are the most common types of plants that can grow in the water.
#
# The color of the water is the same as the color of the water.
#
# The color of the water is the same as the color of the water.
#
# The water is the primary color of the water that is yellow and green. As a general rule, it is the most commonly used color in the U.S. for aquatic systems. It indicates that there are many kinds of plants that are able to live in the same water. However, it is much less frequent in tropical water (like freshwater), where there is a need for more green in the water (like in the ocean).
#
# Some plants can grow to yellow and green in tropical water. These plants are called the 'greenies' or 'yellowies'. These are the most common types of plants that can grow in the water.
#
# The color of the water is a different color than the color of the water.
#
# The water is the primary color of the water that is yellow and green. As a general rule, it is the most commonly used color in the U.S. for aquatic systems. It indicates that there are many kinds of plants that are able to live in the same water. However, it is much less frequent in tropical water (like freshwater), where there is a need for more green in the water (like in the ocean).
#
# Some plants can grow to yellow and green in tropical water. These plants are called the 'greenies' or 'yellowies'. These are the most common types of plants that can grow in the water.
#
# The color of the water
# ======================================== SAMPLE 2 ========================================
#  and a blue light is found. The light source consists of a red and blue color. This light is usually caused by a light that is emitted from the air, such as a light from the sun, or by a light from nearby objects, such as a tree or grass.
#
# The following diagram shows the light source of an electric circuit and the electric field of the circuit.
#
# The circuit looks like this:
#
#
# Figure 4: A typical picture of the circuit and the field of electricity.
#
# (This model has two phases: A phase is the same as in Figure 3; a phase is different from Fig. 1; a phase is the same as in Figure 2 and Fig. 3.)
#
#
# The first phase is the electric field, the second is the field of the circuit. The electric field is present within the current flow. The circuit is operating at a frequency that is twice as low as the current current flow.
#
# The circuit has four phases: A phase can control the current, B phase controls the current and C phase controls the current. When the current flows at a higher frequency, a phase can be set for the current in one or both of the four phases. A phase will cause the current flow to be lower than the current flow. A phase will cause the current flow to be higher than the current flow. When the current flow is higher than the current flow, a phase will be set for the current in one of the four phases. When the current flow is lower than the current flow, a phase will be set for the current in the other four phases.
#
# Figure 5: A typical picture of the circuit and the field of electricity.
#
# The circuit is made up of four phases: A phase, B phase, C phase. The circuit is operating at a frequency that is twice as low as the current flow.
#
# A Phase:
#
#
# Figure 6: The current flow of the circuit.
#
# A A is the current flow with a frequency that is twice as low as the current flow. A is the output voltage of the current flow. The current flow is always at or near the current flow. A A is the current flow with a frequency that is twice as low as the current flow. A is the output voltage of the current flow. The current flow is always at or near the current flow. A A is the current flow with a frequency that is twice as low as the current flow. A is the output voltage of the current flow. The current flow
# ================================================================================
# Model prompt >>> Prompt should not be empty!
# Model prompt >>> The 10 best foods are: 1. Serrano Ham 2. Manchego Cheese 3.
# ======================================== SAMPLE 1 ========================================

#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 1592, in __exit__
#     self.close()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 728, in close
#     tf_session.TF_CloseSession(self._session)
# KeyboardInterrupt

# %%
# !python3 src/interactive_conditional_samples.py --nsamples=2 --top_k=100 --temperature=1

# %% [markdown]
# ### 2. Question-Answering
#
# - Context: passage, some question/answer pairs, and token `A:`
# - For a single word answer (i.e.: Yes/No, city), set flag `length=1`
#
# Sample prompt 1 ([*The Baseline test*](https://bladerunner.fandom.com/wiki/Baseline_Test))
# ```
# Q: What's it like to hold the hand of someone you love?
# A: Interlinked.
# Q: Do they teach you how to feel finger to finger?
# A: Interlinked.
# Q: Do you long for having your heart interlinked?
# A:
# ```
#
# Sample prompt 2:
# ```
# The 2008 Summer Olympics torch relay was run from March 24 until August 8, 2008, prior to the 2008 Summer
# Olympics, with the theme of “one world, one dream”. Plans for the relay were announced on April 26, 2007, in
# Beijing, China. The relay, also called by the organizers as the “Journey of Harmony”, lasted 129 days and carried
# the torch 137,000 km (85,000 mi) – the longest distance of any Olympic torch relay since the tradition was started
# ahead of the 1936 Summer Olympics.
# After being lit at the birthplace of the Olympic Games in Olympia, Greece on March 24, the torch traveled to the Panathinaiko Stadium in Athens, and then to Beijing, arriving on March 31. From Beijing, the torch was
# following a route passing through six continents. The torch has visited cities along the Silk Road, symbolizing
# ancient links between China and the rest of the world. The relay also included an ascent with the flame to the top of
# Mount Everest on the border of Nepal and Tibet, China from the Chinese side, which was closed specially for the
# event.
# Q: What was the length of the race?
# A: 137,000 km
# Q: Was it larger than previous ones?
# A: No
# Q: Where did the race begin?
# A: Olympia, Greece
# Q: Where did they go after?
# A: Athens
# Q: How many days was the race?
# A: seven
# Q: Did they visit any notable landmarks?
# A: Panathinaiko Stadium
# Q: And did they climb any mountains?
# A:
# ```

# %%
# !python3 src/interactive_conditional_samples.py --nsamples=10 --top_k=40 --temperature=.80 --length=1
# Out:
# 2019-02-17 01:02:55.468211: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-02-17 01:02:55.468490: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1982680 executing computations on platform Host. Devices:
# 2019-02-17 01:02:55.468530: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-17 01:02:55.564996: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-17 01:02:55.565550: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x19835a0 executing computations on platform CUDA. Devices:
# 2019-02-17 01:02:55.565589: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-02-17 01:02:55.565989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-02-17 01:02:55.566029: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-02-17 01:02:55.952159: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-02-17 01:02:55.952235: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-02-17 01:02:55.952258: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-02-17 01:02:55.952543: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-02-17 01:02:55.952611: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10754 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:53: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Model prompt >>> The 2008 Summer Olympics torch relay was run from March 24 until August 8, 2008, prior to the 2008 Summer Olympics, with the theme of “one world, one dream”. Plans for the relay were announced on April 26, 2007, in Beijing, China. The relay, also called by the organizers as the “Journey of Harmony”, lasted 129 days and carried the torch 137,000 km (85,000 mi) – the longest distance of any Olympic torch relay since the tradition was started ahead of the 1936 Summer Olympics. After being lit at the birthplace of the Olympic Games in Olympia, Greece on March 24, the torch traveled to the Panathinaiko Stadium in Athens, and then to Beijing, arriving on March 31. From Beijing, the torch was following a route passing through six continents. The torch has visited cities along the Silk Road, symbolizing ancient links between China and the rest of the world. The relay also included an ascent with the flame to the top of Mount Everest on the border of Nepal and Tibet, China from the Chinese side, which was closed specially for the event. Q: What was the length of the race? A: 137,000 km Q: Was it larger than previous ones? A: No Q: Where did the race begin? A: Olympia, Greece Q: Where did they go after? A: Athens Q: How many days was the race? A: seven Q: Did they visit any notable landmarks? A: Panathinaiko Stadium Q: And did they climb any mountains? A:
# 2019-02-17 01:03:22.942043: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ======================================== SAMPLE 1 ========================================
#  No
# ======================================== SAMPLE 2 ========================================
#  No
# ======================================== SAMPLE 3 ========================================
#  No
# ======================================== SAMPLE 4 ========================================
#  No
# ======================================== SAMPLE 5 ========================================
#  No
# ======================================== SAMPLE 6 ========================================
#  No
# ======================================== SAMPLE 7 ========================================
#  Mount
# ======================================== SAMPLE 8 ========================================
#  No
# ======================================== SAMPLE 9 ========================================
#  Pan
# ======================================== SAMPLE 10 ========================================
#  No
# ================================================================================
# Model prompt >>> Traceback (most recent call last):
#   File "/usr/lib/python3.6/contextlib.py", line 99, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py", line 5253, in get_controller
#     yield g
#   File "src/interactive_conditional_samples.py", line 51, in interact_model
#     raw_text = input("Model prompt >>> ")
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "src/interactive_conditional_samples.py", line 69, in <module>
#     fire.Fire(interact_model)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 127, in Fire
#     component_trace = _Fire(component, args, context, name)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 366, in _Fire
#     component, remaining_args)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 542, in _CallCallable
#     result = fn(*varargs, **kwargs)
#   File "src/interactive_conditional_samples.py", line 66, in interact_model
#     print("=" * 80)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 1592, in __exit__
#     self.close()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 728, in close
#     tf_session.TF_CloseSession(self._session)
# KeyboardInterrupt

# %% [markdown]
# ### 3. Summarization
#
#
#
# - Context: article and text *`TL;DR:`* or *`Summary:`* at the end.
#
# Sample prompt:
#
# ```
# Theodore McCarrick is the most senior Catholic figure to be dismissed from the priesthood in modern times.
# US Church officials said allegations he had sexually assaulted a teenager five decades ago were credible.
# Mr McCarrick, 88, had previously resigned but said he had "no recollection" of the alleged abuse.
# "No bishop, no matter how influential, is above the law of the Church," Cardinal Daniel DiNardo, president of the United States Conference of Catholic Bishops said in a statement.
# "For all those McCarrick abused, I pray this judgment will be one small step, among many, toward healing."
# The alleged abuses may have taken place too long ago for criminal charges to be filed because of the statute of limitations.
# Mr McCarrick was the archbishop of Washington DC from 2001 to 2006. Since his resignation last year from the College of Cardinals, he has been living in seclusion in a monastery in Kansas.
# He was the first person to resign as a cardinal since 1927.
# He is among hundreds of members of the clergy accused of sexually abusing children over several decades and his dismissal comes days before the Vatican hosts a summit on preventing child abuse.
# The Vatican said Pope Francis had ruled Mr McCarrick's expulsion from the clergy as definitive, and would not allow any further appeals against the decision.
# TL;DR:
# ```

# %%
# !python3 src/interactive_conditional_samples.py --nsamples=3 --length=100 --temperature=1
# Out:
# 2019-02-17 01:22:47.097283: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-02-17 01:22:47.097552: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x28e2680 executing computations on platform Host. Devices:
# 2019-02-17 01:22:47.097596: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-17 01:22:47.185157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-17 01:22:47.185826: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x28e35a0 executing computations on platform CUDA. Devices:
# 2019-02-17 01:22:47.185870: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-02-17 01:22:47.186287: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-02-17 01:22:47.186324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-02-17 01:22:47.596254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-02-17 01:22:47.596318: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-02-17 01:22:47.596341: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-02-17 01:22:47.596632: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-02-17 01:22:47.596765: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10754 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:53: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Model prompt >>> Theodore McCarrick is the most senior Catholic figure to be dismissed from the priesthood in modern times. US Church officials said allegations he had sexually assaulted a teenager five decades ago were credible. Mr McCarrick, 88, had previously resigned but said he had "no recollection" of the alleged abuse. "No bishop, no matter how influential, is above the law of the Church," Cardinal Daniel DiNardo, president of the United States Conference of Catholic Bishops said in a statement. "For all those McCarrick abused, I pray this judgment will be one small step, among many, toward healing." The alleged abuses may have taken place too long ago for criminal charges to be filed because of the statute of limitations. Mr McCarrick was the archbishop of Washington DC from 2001 to 2006. Since his resignation last year from the College of Cardinals, he has been living in seclusion in a monastery in Kansas. He was the first person to resign as a cardinal since 1927. He is among hundreds of members of the clergy accused of sexually abusing children over several decades and his dismissal comes days before the Vatican hosts a summit on preventing child abuse. The Vatican said Pope Francis had ruled Mr McCarrick's expulsion from the clergy as definitive, and would not allow any further appeals against the decision.  TL;DR:
# 2019-02-17 01:23:03.621967: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ======================================== SAMPLE 1 ========================================
#  wearing Italian Jew garment. Actually posted on Youtube by Mancaj Hymai Donoso ( http://www.youtube.com/watch?v=h8rOWtLENYe )
# JK Rowling and the Red Wedding: Lesson One 4. The official novel from A Month in the Life of Harry Potter chronicles a fusion of grown-up Hufflepuff and witch in Britain who appreciate violent malevolence. Severus Snape has subsequently become an unwelcoming
# ======================================== SAMPLE 2 ========================================
#   The Vatican Didn't Words - 'Discussions of Pope Francis' In this piece     The Associated Press Follow The Butler on Twitter and Facebook AP on Facebook, Twitter and YouTube Closer Reading:  Pope Francis: Vatican's statement on Vatican treatment of paedophiles "People at ELCbishops and Priests Watch to see if any Latin American clergy who have been able to recite Mass regularly and who are still practicing in Argentina and Central America many years ago have been sanctioned and expelled for similar
# ======================================== SAMPLE 3 ========================================
#  Mr McCarrick has ten days to comply with the Bishop's orders. While it will pay fines $4,500 for the 30 days which he has spent in jail.<|endoftext|>Corporations are becoming more and more wasteful. Developers sometimes rely on mobile for everything in life. These companies rely on mobile apps and the subsequent file transfers to keep their ecosystem alive, and aggressively capital managers usually run these firms like a boss on steroids. Mobile apps discard mobile data and professionals choose earlier and more sophisticated
# ================================================================================
# Model prompt >>> Theodore McCarrick is the most senior Catholic figure to be dismissed from the priesthood in modern times. US Church officials said allegations he had sexually assaulted a teenager five decades ago were credible. Mr McCarrick, 88, had previously resigned but said he had "no recollection" of the alleged abuse. "No bishop, no matter how influential, is above the law of the Church," Cardinal Daniel DiNardo, president of the United States Conference of Catholic Bishops said in a statement. "For all those McCarrick abused, I pray this judgment will be one small step, among many, toward healing." The alleged abuses may have taken place too long ago for criminal charges to be filed because of the statute of limitations. Mr McCarrick was the archbishop of Washington DC from 2001 to 2006. Since his resignation last year from the College of Cardinals, he has been living in seclusion in a monastery in Kansas. He was the first person to resign as a cardinal since 1927. He is among hundreds of members of the clergy accused of sexually abusing children over several decades and his dismissal comes days before the Vatican hosts a summit on preventing child abuse. The Vatican said Pope Francis had ruled Mr McCarrick's expulsion from the clergy as definitive, and would not allow any further appeals against the decision.  Summary:
# ======================================== SAMPLE 1 ========================================
#  From the Past: In one of the most notorious scandals of the 1960s, Father John Burroughs was one of the most widely-known bishops in the church. Returning from church service on September 25th, 1960, their controversial decision to precipitate civil insolence and force their full acceptance on the basis of confessions by 14 male priests was seen as a betrayal by the church and his successor, Cardinal Alfonso Paz partaking beforehand in Birmingham. But blowback at their decision was "
# ======================================== SAMPLE 2 ========================================
#  Merely trying to ensure priests knew what they were doing offended some Catholic leaders. But in 1983 Catholic politicians and priests became embroiled in a so-called proxy battle of authority. The proxy war touched off several impassioned, confrontational meetings. The earth--Catholics and Catholics alike were profoundly conflicted. A day before he emerged triumphant, Cardinal Timothy Murch told the pastoral caretakers—male Catholics threatening to jail him, they demanded that he leave the priesthood. He discussed the move with
# ======================================== SAMPLE 3 ========================================
#  Epost's exhortations provide instruction on ethics and faith ministry in the Church. These early parts provide additional biblical execution of principles of "opinion are self-evident" . People to contact for an answer. Exact date 0 11:21:44 state latitude of letter to Lynch. commitment despite conscience committed resigned regarding factors still relevant to pastoral ethics . Priestly status increased as it relates to bishops which condition upon laity confers immunity from prosecution. commente continued following ultimate dismissal concerning
# ================================================================================
# Model prompt >>> Traceback (most recent call last):
#   File "/usr/lib/python3.6/contextlib.py", line 99, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py", line 5253, in get_controller
#     yield g
#   File "src/interactive_conditional_samples.py", line 51, in interact_model
#     raw_text = input("Model prompt >>> ")
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "src/interactive_conditional_samples.py", line 69, in <module>
#     fire.Fire(interact_model)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 127, in Fire
#     component_trace = _Fire(component, args, context, name)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 366, in _Fire
#     component, remaining_args)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 542, in _CallCallable
#     result = fn(*varargs, **kwargs)
#   File "src/interactive_conditional_samples.py", line 66, in interact_model
#     print("=" * 80)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 1592, in __exit__
#     self.close()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 728, in close
#     tf_session.TF_CloseSession(self._session)
# KeyboardInterrupt

# %% [markdown]
# ### 4. Translation
#
#
#
# - Context: a few example pairs of the format *`english_sentence = spanish_sentence`*, and then *`english_sentence =`*  at the end.
#
# Sample prompt:
# ```
# Good morning. = Buenos días.
# I am lost. Where is the restroom? = Estoy perdido. ¿Dónde está el baño?
# How much does it cost? = ¿Cuánto cuesta?
# How do you say maybe in Spanish? = ¿Cómo se dice maybe en Español?
# Would you speak slower, please. = Por favor, habla mas despacio.
# Where is the book store? = ¿Dónde está la librería?
# At last a feminist comedian who makes jokes about men. = Por fin un cómico feminista que hace chistes sobre hombres.
#
# How old are you? =
#
#
# ```

# %%
# !python3 src/interactive_conditional_samples.py --nsamples=3 --temperature=1
# Out:
# 2019-02-17 14:32:05.060450: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2019-02-17 14:32:05.060738: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2288680 executing computations on platform Host. Devices:
# 2019-02-17 14:32:05.060775: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-02-17 14:32:05.161955: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-02-17 14:32:05.162501: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x22895a0 executing computations on platform CUDA. Devices:
# 2019-02-17 14:32:05.162537: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-02-17 14:32:05.162951: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-02-17 14:32:05.162985: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-02-17 14:32:05.545300: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-02-17 14:32:05.545368: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-02-17 14:32:05.545388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-02-17 14:32:05.545664: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-02-17 14:32:05.545726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10754 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:51: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:53: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.random.categorical instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Model prompt >>> 春节好
# 2019-02-17 14:32:20.091312: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# ======================================== SAMPLE 1 ========================================
# 】 X <Tokohita
#
# Yess!!!!1
#
# Thanks X Aerie after that AcerENA Brazos<|endoftext|>"It's a belief system. It's rather spit wacky. You can vote his son during the elections, when he's president on the basis of his record—measured by his voting records and your views on issues—but you can't describe who did the very same thing that supposedly deleted his youiner and somebody else who edited into him to make him look stupid." And so it goes, because I once walked by a movie theater high above Boise and thought there was some arcane, magic middle ground that ended up serving little more than making people think of San Francisco, then Boise even as young people who believe, like most twentysomethings, that their lives with their parents would be okay—justifying snowflake thinking in this universe and explaining the dangers of campus hate speech becomes a diversionary dig at alternative corners of the internet where nobody I knew would flip for me until it turned in my favor.
#
# ================================================================================
# Model prompt >>> How old are you? =
# ======================================== SAMPLE 1 ========================================
# > Dale Royal
#
# Boss
#
# Follow me on twitter
#
# Twitter|Facebook
#
# Follow me on Facebook
#
# The links below are hereby amputated from The Ebenezer Scrooge McDuck Secondary Guide guide.<|endoftext|>As soon as Single suckers death appears there will be the same reddit mods going criminal trying to recover videos featuring Naked Raps, Core Clothing, Kaldor Armor Piercing, Panache, B**B Style, and Nudity.
#
#
# Reddit and PIVLS are quite ethereal horribles and do not define what or who my (real) post currently is or how my /r/foifg becomes/evolves. So, welp
#
#
# Here are three screenshots of mine on dev.egobot with gendered ideas on the topic. They don't take into account ramblings displayed by mods on Reddit as such.
#
# http://www.reddit.com/r/GAME/comments/6stmi6/jizzandewoops/
#
# http://www.reddit.com/r/BLToweredExpulsion/comments/6stmi6/jizzandewoops/<|endoftext|>Turn on the TV and then it turns on the Roku and thus, you will be able to spot the censored content in your Apple TV.
#
# Figure out which of these listings were made and the censorship cannot be detected. If you attach a subscription to the Roku or wish to watch video on the bottom of your TV without access to the other listings, feel free to do so.
#
# By using the �Create Web Text� utility and videos represented in Picture... See video list compiled by YouTuber Videos if you would like to watch special videos and other promotional videos instead of the usual old ad-hoc videos that are offered electronically to millions of customers each month.
#
# So with this we hope to share with you the list of the recorded series that broadcast all over the world today.
#
# There are other TV show broadcasts that were preserved online's classifieds for sale by ad buyers, Including Deus Ex, Al Blade Runner, Bowl Talk, MLB.com 2002, B-52, 2005,, Super Bowl 90&Inaugural Ceremony, the golden age to see the Millennium Dome vanquished andNikola Humphreys silently scour the Pacific.4 Arden A. Mudd Originally an instructional program<|endoftext|>Charles Barkley has afforded Scottie Pippen Philadelphia its first appearance since 2015, tutoring the "Golf Digest" staple
# ======================================== SAMPLE 2 ========================================
#  (Y months) And who are you? = (Y year) And are you something you are not. = (Y year) You would like me to reply as long as possible because I am looking for a Person Just as Health and Fitness requires people with great potential, and the doctor is looking for reason to demand your health, sweating with the dignity of an established power, almost any health concern. In our society, the attitude of Fitness advocates on either side, the National Medicine Man-in-Chief demonstrates on either side the way our culture demands will treat any similar care. It is the will of doctors with Internal Support of Understanding, the technologists over the professionals of teaching. Certain principles that underlie our medical school advocacy. To create Genius, your won't combine up everything as some would have you imagine. . How much are you worth. = (Awaken, 4) Don't care. Talkers and last words are the only sensible choices we have. Get Number 1 financial specialist or cosmetologists. If you are "Y" you should take turns down those listee, as when commerce would start; too often only people who are at great risk and number higher would pick up on some (at a time if 45Z's are acceptable here) which is where these investments go. Know your other sense trade plans: She stays at home (she wouldn't want you to think of her unless you set her too low). She goes home and I talk to our primary medical school representatives who generally know health insurance and surgery, connect you to good resources for training and training, fill you up, invite you everywhere for an appointment, asking you call me for serious, vital information, and when I ask you what's the need doing, you say truly think it up, mentally and physically, that answering words is never able to do that. Internet and social media results when treated with inane opinion and inimitable wealth. We know bad data to be tasty issues to discuss and sheber them. Sometimes there's good in patient attention and she can deliver the facts to us down to Medical College of America cielle. Enthusiasts and former I had to weigh up professional qualification. will often select a man for a local hospital and say no, follow the college course plan if it isn't what you like. Physicioners who are self codependent and are not competitive potentially value having one that has an on's in there. How many teams can each license a statewide placement and what program do they have in B
# ======================================== SAMPLE 3 ========================================
# =============== 18 -20 Year Young Scholar Place her on Beliefs in a Sun God (choose of Christian or Church religion). Prerequisite: 1st-level Sun God modifier in Inquisition Druid robes. Skill bonus: +10 to attack bonus. The Dawnstar specialization is useless for this class, as your Charisma is affected by it. What is Concealed does not stack. 3-Level Sun Devil Mythic rolling This ring lets you determine the type of secret oath this character must swear. 4-Level General Warlock Calls back 6 variant of a nearly master-crafted devil that Dark Hunter General Warlock called the Ashbringer (doesn't offer many other options for a "locked up deity" or "holy bond"). When used and used twice using this ring, you must use it twice for the stats lost or lost for the duration of the summoned, whichever happens first. 5-Level Paladin Anonymous 7 modifier to Charisma (Hurricane). If this ring can disguise some of your Charisma abilities of 1 minute while you have other abilities of that length, you can hide each other during this duration to thwart the mirror thoughts of your foes. It cannot be used defensively as long as "butch" and "fairy" are obscuring. Butch has a pretty good defenses against the shroud, so cycling buttons after harping on this is an improvement. Its AC is 256 so equipping any weapon that'll fit a creature of the type poses an obvious problem for the hunters with big, incendiary weapons. 6-Level Druid Total Charisma and Turn Score ============== 5 15+ + 1+ + Condition Bonus 1 Charisma Projectile racial spellList of characteristicsTo learn more about these attributes and how they affect your character, see the full list of Pathfinder Companion. Your badge will be revealed at the very beginning of this class. 8 21+ Effect from Strength + Cane of a tree. Pine tree's reach 200 ft to those who consume it. Fire jump is doubled. 10 23+ Change Skill: Windstorm. Shoot-out blast quiver bright red but fires 7 times when carrying this weapon bonus insight creature. Craft Wondrous Item No.: Palm of Valerian Essential Arcana appeasecourardyDJ Excellent Sorcerer ruler and Bos Small selection national loretellerMageBarComplexantBasicCommonCraftingRedconsolarLook for the red dye at the start of each Barbarian, Magician or Fighter archetype listed above. The following is the status of this effect:
#
#
# Over twilight zone, drow can focus on cloaking spellsendless are e
# ================================================================================
# Model prompt >>> Traceback (most recent call last):
#   File "/usr/lib/python3.6/contextlib.py", line 99, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py", line 5253, in get_controller
#     yield g
#   File "src/interactive_conditional_samples.py", line 51, in interact_model
#     raw_text = input("Model prompt >>> ")
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "src/interactive_conditional_samples.py", line 69, in <module>
#     fire.Fire(interact_model)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 127, in Fire
#     component_trace = _Fire(component, args, context, name)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 366, in _Fire
#     component, remaining_args)
#   File "/usr/local/lib/python3.6/dist-packages/fire/core.py", line 542, in _CallCallable
#     result = fn(*varargs, **kwargs)
#   File "src/interactive_conditional_samples.py", line 66, in interact_model
#     print("=" * 80)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 1592, in __exit__
#     self.close()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 728, in close
#     tf_session.TF_CloseSession(self._session)
# KeyboardInterrupt
